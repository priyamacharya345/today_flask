# %%
import matplotlib.pyplot as plt

# %%
x=10

# %%
y=20

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'rx')
plt.show()

# %%
plt.plot(x,y,'mO')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(x,y,'mO')
#       2 plt.show()
#
# File C:\Python311\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File C:\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
# ...

# %%
plt.plot(x,y,'m0')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.plot(x,y,'m0')
#       2 plt.show()
#
# File C:\Python311\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File C:\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
# ...

# %%
plt.plot(x,y,'mo')
plt.show()

# %%
plt.plot(x,y,'ch')
plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
y=[7,14,21,28,35,42,49,56,63]
plt.plot(x,y,'gs')
plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
y=[7,14,21,28,35,42,49,56,63]
plt.plot(x,y)
plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
y=[7,14,21,28,35,42,49,56,63]
plt.plot(x,y,'mo:")
plt.show()
# Out:
#   Cell In[12], line 3
#     plt.plot(x,y,'mo:")
#                  ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
x=[10,20,30,40,50,60,70,80,90]
y=[7,14,21,28,35,42,49,56,63]
plt.plot(x,y,'mo:')
plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
y=[7,14,21,28,35,42,49,56,63]
plt.plot(x,y,'mo:',markersize=9,linewidth=3)
plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
y=[7,14,21,28,35,42,49,56,63]
plt.plot(x,y,'mo:',markersize=9,linewidth=3)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x=['China','India','USA','Indoneshia','Bangladesh','Pakistan']

# %%
y=[12345678934,123456784,1234567567,123456563,99999999999,99999999999999]

# %%
x
# Out:
# ['China', 'India', 'USA', 'Indoneshia', 'Bangladesh', 'Pakistan']

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
y
# Out:
# [123456789, 12345678, 1234567, 123456, 99999999999, 99999999999999]

# %%
x
# Out:
# ['China', 'India', 'USA', 'Indoneshia', 'Bangladesh', 'Pakistan']

# %%
y
# Out:
# [123456789, 12345678, 1234567, 123456, 99999999999, 99999999999999]

# %%
plt.xlabel("name of the country")
plt.ylabel("population")
plt.title("Allah party be alert")
plt.bar(x,y)
plt.show()

# %%
x
# Out:
# ['China', 'India', 'USA', 'Indoneshia', 'Bangladesh', 'Pakistan']

# %%
y
# Out:
# [12345678934, 123456784, 1234567567, 123456563, 99999999999, 99999999999999]

# %%
plt.xlabel("name of the country")
plt.ylabel("population")
plt.title("Allah party be alert")
plt.bar(x,y)
plt.show()

# %%
y=[992345678934, 91123456784, 9234567567, 923456563, 999999999, 99999999999]

# %%
plt.xlabel("name of the country")
plt.ylabel("population")
plt.title("Allah party be alert")
plt.bar(x,y)
plt.show()

# %%
y=[92345678934, 61123456784, 79234567567, 88923456563, 999999999, 99999999999]

# %%
plt.xlabel("name of the country")
plt.ylabel("population")
plt.title("Allah party be alert")
plt.bar(x,y)
plt.show()
